# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
import newsapi
import wordcloud
import numpy
nltk.download('vader_lexicon')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\jayri\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jayri\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jayri\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jayri\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
btc_headlines = newsapi.get_everything(
    q="Bitcoin",
    language="en",
    sort_by="relevancy"
)

# %%
# Fetch the Ethereum news articles
eth_headlines = newsapi.get_everything(
    q="Ethereum",
    language="en",
    sort_by="relevancy"
)

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sentiments = []

for article in btc_headlines["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "text": text,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
btc_df = pd.DataFrame(btc_sentiments)

# Reorder DataFrame columns
cols = ["text", "compound", "positive", "negative", "neutral"]
btc_df = btc_df[cols]

btc_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  El Salvador's President Nayib Bukele has made ...    0.8402     0.282
# 1  El Salvador has become the first country in th...    0.1280     0.043
# 2  It's all about clean energy, it seems. \r\nElo...    0.6908     0.169
# 3  image captionThe move means bitcoin will be ac...    0.2732     0.060
# 4  Several crypto fans that descended on Miami, F...    0.5574     0.107
#
#    negative  neutral
# 0       0.0    0.718
# 1       0.0    0.957
# 2       0.0    0.831
# 3       0.0    0.940
# 4       0.0    0.893

# %%
# Create the Ethereum sentiment scores DataFrame
eth_sentiments = []

for article in eth_headlines["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "text": text,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
eth_df = pd.DataFrame(eth_sentiments)

# Reorder DataFrame columns
cols = ["text", "compound", "positive", "negative", "neutral"]
eth_df = eth_df[cols]

eth_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  TL;DR: The Cryptocurrency with Ethereum and So...     0.000       0.0
# 1  It wasn't long ago that your average person ha...    -0.296       0.0
# 2  A representation of virtual currency Ethereum ...     0.000       0.0
# 3  This article was translated from our Spanish e...    -0.340       0.0
# 4  This new mining feature is called 'Norton Cryp...     0.000       0.0
#
#    negative  neutral
# 0     0.000    1.000
# 1     0.061    0.939
# 2     0.000    1.000
# 3     0.066    0.934
# 4     0.000    1.000

# %%
# Describe the Bitcoin Sentiment
btc_df.describe()
# Out:
#         compound   positive  negative    neutral
# count  20.000000  20.000000  20.00000  20.000000
# mean    0.166260   0.074800   0.03000   0.895150
# std     0.395053   0.069831   0.03939   0.064774
# min    -0.557400   0.000000   0.00000   0.718000
# 25%    -0.050575   0.032250   0.00000   0.844750
# 50%     0.165150   0.065500   0.00000   0.910500
# 75%     0.401050   0.105500   0.06200   0.938500
# max     0.840200   0.282000   0.10700   1.000000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.081370   0.044550   0.020650   0.934800
# std     0.345267   0.061021   0.040732   0.067162
# min    -0.458800   0.000000   0.000000   0.782000
# 25%    -0.068300   0.000000   0.000000   0.917000
# 50%     0.000000   0.000000   0.000000   0.936500
# 75%     0.361200   0.073000   0.015250   1.000000
# max     0.778300   0.191000   0.151000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: BTC with a mean positive of 0.074800
#
# Q: Which coin had the highest compound score?
#
# A: BTC with a max compound score of 0.840200
#
# Q. Which coin had the highest positive score?
#
# A: BTC with a max positive score of 0.282000

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()
# Create a list of stopwords
sw = stopwords.words('english')
# Expand the default stopwords list if necessary
# e.g. stop.append("it'")

# %%
# Lorenzo's Code

# # Complete the tokenizer function
# def tokenizer(text):
#     """Tokenizes text."""
    
#     # Create a list of the words
#     words = word_tokenize(text)

#     # Convert the words to lowercase
#     words = list(filter(lambda w: w.lower(), words))
    
#     # Remove the punctuation
#     words = list(filter(lambda t: t not in punctuation, words))
    
#     # Remove the stopwords
#     words = list(filter(lambda t: t.lower() not in stop, words))
    
#     # Lemmatize Words into root words
#     tokens = [wnl.lemmatize(word) for word in words]
    
#     return tokens

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    words = word_tokenize(text)
    # Remove the punctuation from text
    words = list(filter(lambda t: t not in punctuation, words))

    # Create a tokenized list of the words
    # already done
    
    # Lemmatize words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words]
    tokens = [word.lower() for word in tokens if word.lower() not in sw]

   
    # Convert the words to lowercase
    # words = list(filter(lambda t: t.lower() not in sw, words))

    # Remove the stop words
    # words = list(filter(lambda t: t.lower() not in sw, words))

    
    return tokens

# %%
# Create a new tokens column for Bitcoin
btc_df['tokens'] = btc_df.text.apply(tokenizer)

# %%
btc_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  El Salvador's President Nayib Bukele has made ...    0.8402     0.282
# 1  El Salvador has become the first country in th...    0.1280     0.043
# 2  It's all about clean energy, it seems. \r\nElo...    0.6908     0.169
# 3  image captionThe move means bitcoin will be ac...    0.2732     0.060
# 4  Several crypto fans that descended on Miami, F...    0.5574     0.107
#
#    negative  neutral                                             tokens
# 0       0.0    0.718  [el, salvador, 's, president, nayib, bukele, h...
# 1       0.0    0.957  [el, salvador, ha, become, first, country, wor...
# 2       0.0    0.831  ['s, clean, energy, seems, elon, musk, tesla, ...
# 3       0.0    0.940  [image, captionthe, move, mean, bitcoin, accep...
# 4       0.0    0.893  [several, crypto, fan, descended, miami, flori...

# %%
# Create a new tokens column for Ethereum
eth_df['tokens'] = eth_df.text.apply(tokenizer)

# %%
eth_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  TL;DR: The Cryptocurrency with Ethereum and So...     0.000       0.0
# 1  It wasn't long ago that your average person ha...    -0.296       0.0
# 2  A representation of virtual currency Ethereum ...     0.000       0.0
# 3  This article was translated from our Spanish e...    -0.340       0.0
# 4  This new mining feature is called 'Norton Cryp...     0.000       0.0
#
#    negative  neutral                                             tokens
# 0     0.000    1.000  [tl, dr, cryptocurrency, ethereum, solidity, b...
# 1     0.061    0.939  [wa, n't, long, ago, average, person, clue, nf...
# 2     0.000    1.000  [representation, virtual, currency, ethereum, ...
# 3     0.066    0.934  [article, wa, translated, spanish, edition, us...
# 4     0.000    1.000  [new, mining, feature, called, 'norton, crypto...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin Ngrams where N=2
N = 2
grams1 = ngrams(tokenizer(btc_df.text.str.cat()), N)
Counter(grams1).most_common(10)
# Out:
# [(('el', 'salvador'), 7),
#  (('bitcoin', 'legal'), 6),
#  (('legal', 'tender'), 5),
#  (('reuters', 'el'), 4),
#  (('central', 'american'), 3),
#  (('president', 'nayib'), 2),
#  (('nayib', 'bukele'), 2),
#  (('salvador', 'ha'), 2),
#  (('ha', 'become'), 2),
#  (('become', 'first'), 2)]

# %%
# Generate the Ethereum N-grams where N=2
N = 2
grams2 = ngrams(tokenizer(eth_df.text.str.cat()), N)
Counter(grams2).most_common(10)
# Out:
# [(('digital', 'yuan'), 3),
#  (('cryptocurrency', 'ethereum'), 2),
#  (('non-fungible', 'token'), 2),
#  (('yao', 'qian'), 2),
#  (('qian', 'former'), 2),
#  (('former', 'head'), 2),
#  (('head', 'china'), 2),
#  (('china', "'s"), 2),
#  (("'s", 'digital'), 2),
#  (('char', 'bitcoin'), 2)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
token_count(ngrams(tokenizer(btc_df.text.str.cat()), 1), N=10)
# Out:
# [(('char',), 20),
#  (('bitcoin',), 15),
#  (('salvador',), 9),
#  (('cryptocurrency',), 8),
#  (('…',), 8),
#  (('el',), 7),
#  (("'s",), 6),
#  (('legal',), 6),
#  (('ha',), 5),
#  (('tender',), 5)]

# %%
# Use token_count to get the top 10 words for Ethereum
token_count(ngrams(tokenizer(eth_df.text.str.cat()), N), N=10)
# Out:
# [(('digital', 'yuan'), 3),
#  (('cryptocurrency', 'ethereum'), 2),
#  (('non-fungible', 'token'), 2),
#  (('yao', 'qian'), 2),
#  (('qian', 'former'), 2),
#  (('former', 'head'), 2),
#  (('head', 'china'), 2),
#  (('china', "'s"), 2),
#  (("'s", 'digital'), 2),
#  (('char', 'bitcoin'), 2)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
corpus = btc_df["text"]

def process_text(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return ' '.join(output)

big_string = ' '.join(corpus)
input_text = process_text(big_string)

wc = WordCloud().generate(input_text)
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
corpus = eth_df["text"]

def process_text(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return ' '.join(output)

big_string = ' '.join(corpus)
input_text = process_text(big_string)

wc = WordCloud().generate(input_text)
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: en-core-web-sm==3.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl#egg=en_core_web_sm==3.0.0 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (3.0.0)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.5.2)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.19.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.4)
# Requirement already satisfied: jinja2 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: setuptools in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (50.3.1.post20201107)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.2 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4; python_version < "3.8" in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.7.4.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.50.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.25.1)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.2.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.7)
# Requirement already satisfied: six in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.1)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.26.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.10)
# Requirement already satisfied: boto3 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.17.96)
# Requirement already satisfied: botocore<1.21.0,>=1.20.96 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.20.96)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.4.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\jayri\anaconda3\envs\dev\lib\site-packages (from botocore<1.21.0,>=1.20.96->boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.8.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
btc_text = btc_df["text"].str.cat()

# %%
# Run the NER processor on all of the text
doc = nlp(btc_text)
# Add a title to the document
doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nayib Bukele
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has made good on his promise to adopt Bitcoin as legal tender. Officials in the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Central American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  country's congress voted to accept the cryptocurrency by a majori… [+1414 chars]El
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has become the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  country in the world to recognize the cryptocurrency bitcoin as legal currency, according to President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nayib Bukele
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in a tweet on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Citizens
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  caused ripples in the cryptocurrency market in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past few months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  by announcing that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had bought
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1.5 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth of bitcoi… [+2508 chars]image captionThe move means bitcoin will be accepted everywhere for goods and services, alongside the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has become the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  country in the world to officially classify
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  a… [+2233 chars]Several crypto fans that descended on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Miami
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Florida
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  for the largest bitcoin conference in history are now saying theyve tested positive for
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     covid-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Larry Cermak
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-he

# %%
# List all Entities
print([ent.text for ent in doc.ents if ent.label_ == 'GPE'])
# Out:
# ["El Salvador's", 'US', 'El Salvador', 'Miami', 'Florida', 'US', 'US', 'Iran', 'U.S.', 'El Salvador', 'U.S.', 'El Salvador', 'El Salvador', 'El Salvador', 'U.S.', 'US', 'Indonesia', 'Dogecoin']

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_text = eth_df["text"].str.cat()

# %%
# Run the NER processor on all of the text
doc = nlp(eth_text)
# Add a title to the document
doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">TL;DR: The Cryptocurrency with Ethereum and Solidity Blockchain Developer Bundle is on sale for £
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     21.25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  as of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 17
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , saving you
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     97%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# </br>Is everyone you know investing in cryptocurrency? … [+949 chars]It wasn't long ago that your average person had no clue what an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was. Nowadays, they're making headlines for selling for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hundreds of thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of bucks. Predictably, folks are learning about NFTs … [+3056 chars]A representation of virtual currency
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is seen in front of a stock graph in this illustration taken
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February 19, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . REUTERS/Dado Ruvic/Illustration/File PhotoCryptocurrency Ethereum extende… [+1099 chars]This article was translated from our
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spanish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  edition using
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Last May
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , VitaliK
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buterin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  became the youngest billionaire in the world at just
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     27
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ye… [+2422 chars]This new mining feature is called 'Norton Crypto' and will be rolling out
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tomorrow
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Norton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  360 users enrolled in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Norton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's early adopter program. When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Norton Crypto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is enabled, the software will use… [+631
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chars]&quot;We
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  are building a team&quot; the page declares, stating: &quot;We welcome exceptional engineers (solidity, react, python), designers, gamers, marketers, and community leaders. If you want to join our team, se… [+478 chars]Opinions expressed by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Entrepreneur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Launched in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and having racked up
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than one million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  users already,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SafeMoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a blockchain-based cryptocurrency similar … [+3939 chars]CryptoPunks represent the only historically relevant narrative upon which value could conceivably live for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em

# %%
# List all Entities
print([ent.text for ent in doc.ents if ent.label_ == 'GPE'])
# Out:
# ['Indonesia', 'China', 'China']

# %% [markdown]
# ---
